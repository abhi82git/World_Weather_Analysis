# %%
# Import the dependencies.
import pandas as pd
import requests
import gmaps

# Import the API key.
from config import weather_api_key

# Import the NumPy module.
import numpy as np

# Import the time library and the datetime module from the datetime library 
import time

from datetime import datetime

# %%
lats = np.random.uniform(-90,90,size = 2000)
lngs = np.random.uniform(-180,180, size = 2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Empty city list
cities = []

# loop through all coordiantes
for location in coordinates:
    city = citipy.nearest_city(location[0], location[1]).city_name
    if city not in cities:
        cities.append(city)
    
# print the ciy list
print(cities)

# print the city count
print(len(cities))
# Out:
# ['avarua', 'taolanaro', 'los llanos de aridane', 'hobart', 'castro', 'cabo san lucas', 'punta arenas', 'boguchany', 'jamestown', 'mataura', 'mar del plata', 'hermanus', 'grand river south east', 'souillac', 'half moon bay', 'upernavik', 'tasiilaq', 'rikitea', 'lebu', 'attawapiskat', 'yulara', 'port-gentil', 'kapaa', 'la ronge', 'mendeleyevsk', 'samusu', 'saint-philippe', 'hilo', 'sioux lookout', 'faya', 'saint anthony', 'hithadhoo', 'dikson', 'georgiyevskoye', 'atuona', 'saskylakh', 'pokrovsk', 'ushuaia', 'chuy', 'petropavlovsk-kamchatskiy', 'pevek', 'ayan', 'kavaratti', 'usinsk', 'vaini', 'saint george', 'barentsburg', 'sitka', 'yeppoon', 'sao joao da barra', 'arraial do cabo', 'sapao', 'bredasdorp', 'tuktoyaktuk', 'yellowknife', 'lolua', 'panna', 'ponta do sol', 'albany', 'yanan', 'tiksi', 'turayf', 'esperance', 'port elizabeth', 'cape town', 'kawalu', 'nsanje', 'werda', 'tsihombe', 'slave lake', 'sisimiut', 'busselton', 'luderitz', 'salalah', 'puerto ayora', 'chokurdakh', 'constitucion', 'novikovo', 'deputatskiy', 'barrow', 'kytlym', 'rio grande', 'yima', 'illoqqortoormiut', 'nguiu', 'hasaki', 'bangassou', 'bengkulu', 'vargem grande', 'ketchikan', 'santa maria', 'burica', 'okhotsk', 'kruisfontein', 'fairbanks', 'cidreira', 'iqaluit', 'san quintin', 'vestmanna', 'mehamn', 'bekovo', 'kodiak', 'provideniya', 'ancud', 'nchelenge', 'narsaq', 'belushya guba', 'airai', 'bluff', 'port blair', 'butaritari', 'padang', 'coruripe', 'babanusah', 'royan', 'kenai', 'sayaxche', 'nikolskoye', 'bambanglipuro', 'te anau', 'katobu', 'ardesen', 'pisco', 'aasiaat', 'cururupu', 'bartica', 'tadine', 'khandyga', 'cap malheureux', 'berlevag', 'port alfred', 'lavrentiya', 'huron', 'natal', 'new norfolk', 'luanda', 'qaanaaq', 'skegness', 'virginia beach', 'emba', 'faanui', 'sinnamary', 'aksarka', 'sao filipe', 'likasi', 'coihaique', 'thompson', 'jiuquan', 'lasa', 'victoria', 'prachin buri', 'dingle', 'okha', 'nauta', 'macia', 'alofi', 'nanjangud', 'pangoa', 'calabozo', 'solsvik', 'noumea', 'yoichi', 'halalo', 'along', 'bethel', 'brookhaven', 'hobyo', 'saint-joseph', 'viedma', 'goycay', 'porto walter', 'lorengau', 'puerto pinasco', 'alice springs', 'saldanha', 'tautira', 'vila do maio', 'gat', 'marcona', 'husavik', 'katherine', 'mlonggo', 'bakchar', 'limoux', 'luxor', 'mattru', 'chapais', 'cervo', 'ituni', 'bafang', 'klaksvik', 'adrar', 'terrace', 'azul', 'micheweni', 'torbay', 'vardo', 'ust-tsilma', 'suriapet', 'amderma', 'jarjis', 'goderich', 'soyo', 'baruun-urt', 'awbari', 'nizhneyansk', 'araguatins', 'khatanga', 'saint-pierre', 'northlake', 'vila velha', 'gushikawa', 'aklavik', 'sechelt', 'yar-sale', 'codrington', 'longyearbyen', 'nelson bay', 'port moresby', 'rolim de moura', 'georgetown', 'naze', 'atasu', 'fortuna', 'kangaatsiaq', 'kamyzyak', 'kangaba', 'rivera', 'maniwaki', 'mahebourg', 'antananarivo', 'fare', 'shibarghan', 'east london', 'skage', 'hualmay', 'bay roberts', 'bathsheba', 'bambous virieux', 'grindavik', 'diamantino', 'muros', 'nanortalik', 'namibe', 'tremosna', 'ekibastuz', 'lompoc', 'karratha', 'trinidad', 'salamiyah', 'kennett', 'asau', 'jutai', 'isangel', 'korem', 'hofn', 'geraldton', 'zhigansk', 'reefton', 'aktash', 'mrirt', 'paita', 'omsukchan', 'albanel', 'toliary', 'kaitangata', 'mys shmidta', 'broken hill', 'falam', 'branistea', 'henties bay', 'lazaro cardenas', 'timbiqui', 'westport', 'kavieng', 'namatanai', 'larimna', 'dicabisagan', 'hami', 'oistins', 'tura', 'saint-augustin', 'embu', 'samaipata', 'meulaboh', 'artyk', 'daru', 'rungata', 'sana', 'alto baudo', 'guasdualito', 'villa maria', 'nkhata bay', 'tatawin', 'pafos', 'phan thiet', 'linjiang', 'floro', 'carnarvon', 'roald', 'saleaula', 'majene', 'yafran', 'puerto del rosario', 'nanning', 'saint-francois', 'villa union', 'martinsville', 'bintulu', 'zadar', 'bolungarvik', 'mitha tiwana', 'kamaishi', 'hastings', 'chicama', 'inuvik', 'kichera', 'tubmanburg', 'sorland', 'mpanda', 'price', 'ormara', 'ribeira grande', 'beloha', 'lamar', 'fort nelson', 'egvekinot', 'kingaroy', ...
# 725

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of logging
print("Beginning Data Retrieval              ")
print("--------------------------------------")

# Initialize the counters
record_count = 1
set_count = 1

# Looping through cities
for i, city in enumerate(cities):
    
    # creating groups of 50
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)
        
    # Create city url list
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    
    # Log the URl, record and set numbers and city
    print(f"Processing Record {record_count} of Set {set_count}: {city}")
    record_count += 1

    try:
        
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lon = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
        # Append the city information to data list
        city_data.append({"City": city,
                    "Country": city_country,
                    "Latitude": city_lat,
                    "Longitude": city_lon,
                    "Max Temp": city_max_temp,
                    "Humidity": city_humidity,
                    "Cloudiness": city_clouds,
                    "Wind Speed": city_wind,
                    "Current Description": city_weather_desc})

        
    # Log an exception if error occurs in fetching the city
    except:
        print(f"City {city}not found. Skipping.......")
        pass
    
    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=avarua
# Processing Record 1 of Set 1: avarua
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=taolanaro
# Processing Record 2 of Set 1: taolanaro
# City taolanaronot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=los+llanos+de+aridane
# Processing Record 3 of Set 1: los llanos de aridane
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hobart
# Processing Record 4 of Set 1: hobart
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=castro
# Processing Record 5 of Set 1: castro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cabo+san+lucas
# Processing Record 6 of Set 1: cabo san lucas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=punta+arenas
# Processing Record 7 of Set 1: punta arenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=boguchany
# Processing Record 8 of Set 1: boguchany
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=jamestown
# Processing Record 9 of Set 1: jamestown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mataura
# Processing Record 10 of Set 1: mataura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mar+del+plata
# Processing Record 11 of Set 1: mar del plata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hermanus
# Processing Record 12 of Set 1: hermanus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=grand+river+south+east
# Processing Record 13 of Set 1: grand river south east
# City grand river south eastnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=souillac
# Processing Record 14 of Set 1: souillac
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=half+moon+bay
# Processing Record 15 of Set 1: half moon bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=upernavik
# Processing Record 16 of Set 1: upernavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tasiilaq
# Processing Record 17 of Set 1: tasiilaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=rikitea
# Processing Record 18 of Set 1: rikitea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lebu
# Processing Record 19 of Set 1: lebu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=attawapiskat
# Processing Record 20 of Set 1: attawapiskat
# City attawapiskatnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yulara
# Processing Record 21 of Set 1: yulara
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=port-gentil
# Processing Record 22 of Set 1: port-gentil
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kapaa
# Processing Record 23 of Set 1: kapaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=la+ronge
# Processing Record 24 of Set 1: la ronge
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mendeleyevsk
# Processing Record 25 of Set 1: mendeleyevsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=samusu
# Processing Record 26 of Set 1: samusu
# City samusunot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saint-philippe
# Processing Record 27 of Set 1: saint-philippe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hilo
# Processing Record 28 of Set 1: hilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sioux+lookout
# Processing Record 29 of Set 1: sioux lookout
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=faya
# Processing Record 30 of Set 1: faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saint+anthony
# Processing Record 31 of Set 1: saint anthony
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hithadhoo
# Processing Record 32 of Set 1: hithadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=dikson
# Processing Record 33 of Set 1: dikson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=georgiyevskoye
# Processing Record 34 of Set 1: georgiyevskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=atuona
# Processing Record 35 of Set 1: atuona
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saskylakh
# Processing Record 36 of Set 1: saskylakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=pokrovsk
# Processing Record 37 of Set 1: pokrovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ushuaia
# Processing Record 38 of Set 1: ushuaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=chuy
# Processing Record 39 of Set 1: chuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=petropavlovsk-kamchatskiy
# Processing Record 40 of Set 1: petropavlovsk-kamchatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=pevek
# Processing Record 41 of Set 1: pevek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ayan
# Processing Record 42 of Set 1: ayan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kavaratti
# Processing Record 43 of Set 1: kavaratti
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=usinsk
# Processing Record 44 of Set 1: usinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vaini
# Processing Record 45 of Set 1: vaini
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saint+george
# Processing Record 46 of Set 1: saint george
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=barentsburg
# Processing Record 47 of Set 1: barentsburg
# City barentsburgnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sitka
# Processing Record 48 of Set 1: sitka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yeppoon
# Processing Record 49 of Set 1: yeppoon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sao+joao+da+barra
# Processing Record 50 of Set 1: sao joao da barra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=arraial+do+cabo
# Processing Record 1 of Set 2: arraial do cabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sapao
# Processing Record 2 of Set 2: sapao
# City sapaonot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bredasdorp
# Processing Record 3 of Set 2: bredasdorp
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tuktoyaktuk
# Processing Record 4 of Set 2: tuktoyaktuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yellowknife
# Processing Record 5 of Set 2: yellowknife
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lolua
# Processing Record 6 of Set 2: lolua
# City loluanot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=panna
# Processing Record 7 of Set 2: panna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ponta+do+sol
# Processing Record 8 of Set 2: ponta do sol
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=albany
# Processing Record 9 of Set 2: albany
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yanan
# Processing Record 10 of Set 2: yanan
# City yanannot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tiksi
# Processing Record 11 of Set 2: tiksi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=turayf
# Processing Record 12 of Set 2: turayf
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=esperance
# Processing Record 13 of Set 2: esperance
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=port+elizabeth
# Processing Record 14 of Set 2: port elizabeth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cape+town
# Processing Record 15 of Set 2: cape town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kawalu
# Processing Record 16 of Set 2: kawalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nsanje
# Processing Record 17 of Set 2: nsanje
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=werda
# Processing Record 18 of Set 2: werda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tsihombe
# Processing Record 19 of Set 2: tsihombe
# City tsihombenot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=slave+lake
# Processing Record 20 of Set 2: slave lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sisimiut
# Processing Record 21 of Set 2: sisimiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=busselton
# Processing Record 22 of Set 2: busselton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=luderitz
# Processing Record 23 of Set 2: luderitz
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=salalah
# Processing Record 24 of Set 2: salalah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=puerto+ayora
# Processing Record 25 of Set 2: puerto ayora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=chokurdakh
# Processing Record 26 of Set 2: chokurdakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=constitucion
# Processing Record 27 of Set 2: constitucion
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=novikovo
# Processing Record 28 of Set 2: novikovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=deputatskiy
# Processing Record 29 of Set 2: deputatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=barrow
# Processing Record 30 of Set 2: barrow
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kytlym
# Processing Record 31 of Set 2: kytlym
# City kytlymnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=rio+grande
# Processing Record 32 of Set 2: rio grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yima
# Processing Record 33 of Set 2: yima
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=illoqqortoormiut
# Processing Record 34 of Set 2: illoqqortoormiut
# City illoqqortoormiutnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nguiu
# Processing Record 35 of Set 2: nguiu
# City nguiunot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hasaki
# Processing Record 36 of Set 2: hasaki
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bangassou
# Processing Record 37 of Set 2: bangassou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bengkulu
# Processing Record 38 of Set 2: bengkulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vargem+grande
# Processing Record 39 of Set 2: vargem grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ketchikan
# Processing Record 40 of Set 2: ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=santa+maria
# Processing Record 41 of Set 2: santa maria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=burica
# Processing Record 42 of Set 2: burica
# City buricanot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=okhotsk
# Processing Record 43 of Set 2: okhotsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kruisfontein
# Processing Record 44 of Set 2: kruisfontein
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=fairbanks
# Processing Record 45 of Set 2: fairbanks
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cidreira
# Processing Record 46 of Set 2: cidreira
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=iqaluit
# Processing Record 47 of Set 2: iqaluit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=san+quintin
# Processing Record 48 of Set 2: san quintin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vestmanna
# Processing Record 49 of Set 2: vestmanna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mehamn
# Processing Record 50 of Set 2: mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bekovo
# Processing Record 1 of Set 3: bekovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kodiak
# Processing Record 2 of Set 3: kodiak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=provideniya
# Processing Record 3 of Set 3: provideniya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ancud
# Processing Record 4 of Set 3: ancud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nchelenge
# Processing Record 5 of Set 3: nchelenge
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=narsaq
# Processing Record 6 of Set 3: narsaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=belushya+guba
# Processing Record 7 of Set 3: belushya guba
# City belushya gubanot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=airai
# Processing Record 8 of Set 3: airai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bluff
# Processing Record 9 of Set 3: bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=port+blair
# Processing Record 10 of Set 3: port blair
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=butaritari
# Processing Record 11 of Set 3: butaritari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=padang
# Processing Record 12 of Set 3: padang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=coruripe
# Processing Record 13 of Set 3: coruripe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=babanusah
# Processing Record 14 of Set 3: babanusah
# City babanusahnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=royan
# Processing Record 15 of Set 3: royan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kenai
# Processing Record 16 of Set 3: kenai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sayaxche
# Processing Record 17 of Set 3: sayaxche
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nikolskoye
# Processing Record 18 of Set 3: nikolskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bambanglipuro
# Processing Record 19 of Set 3: bambanglipuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=te+anau
# Processing Record 20 of Set 3: te anau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=katobu
# Processing Record 21 of Set 3: katobu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ardesen
# Processing Record 22 of Set 3: ardesen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=pisco
# Processing Record 23 of Set 3: pisco
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=aasiaat
# Processing Record 24 of Set 3: aasiaat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cururupu
# Processing Record 25 of Set 3: cururupu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bartica
# Processing Record 26 of Set 3: bartica
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tadine
# Processing Record 27 of Set 3: tadine
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=khandyga
# Processing Record 28 of Set 3: khandyga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cap+malheureux
# Processing Record 29 of Set 3: cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=berlevag
# Processing Record 30 of Set 3: berlevag
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=port+alfred
# Processing Record 31 of Set 3: port alfred
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lavrentiya
# Processing Record 32 of Set 3: lavrentiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=huron
# Processing Record 33 of Set 3: huron
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=natal
# Processing Record 34 of Set 3: natal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=new+norfolk
# Processing Record 35 of Set 3: new norfolk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=luanda
# Processing Record 36 of Set 3: luanda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=qaanaaq
# Processing Record 37 of Set 3: qaanaaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=skegness
# Processing Record 38 of Set 3: skegness
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=virginia+beach
# Processing Record 39 of Set 3: virginia beach
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=emba
# Processing Record 40 of Set 3: emba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=faanui
# Processing Record 41 of Set 3: faanui
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sinnamary
# Processing Record 42 of Set 3: sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=aksarka
# Processing Record 43 of Set 3: aksarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sao+filipe
# Processing Record 44 of Set 3: sao filipe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=likasi
# Processing Record 45 of Set 3: likasi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=coihaique
# Processing Record 46 of Set 3: coihaique
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=thompson
# Processing Record 47 of Set 3: thompson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=jiuquan
# Processing Record 48 of Set 3: jiuquan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lasa
# Processing Record 49 of Set 3: lasa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=victoria
# Processing Record 50 of Set 3: victoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=prachin+buri
# Processing Record 1 of Set 4: prachin buri
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=dingle
# Processing Record 2 of Set 4: dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=okha
# Processing Record 3 of Set 4: okha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nauta
# Processing Record 4 of Set 4: nauta
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=macia
# Processing Record 5 of Set 4: macia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=alofi
# Processing Record 6 of Set 4: alofi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nanjangud
# Processing Record 7 of Set 4: nanjangud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=pangoa
# Processing Record 8 of Set 4: pangoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=calabozo
# Processing Record 9 of Set 4: calabozo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=solsvik
# Processing Record 10 of Set 4: solsvik
# City solsviknot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=noumea
# Processing Record 11 of Set 4: noumea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yoichi
# Processing Record 12 of Set 4: yoichi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=halalo
# Processing Record 13 of Set 4: halalo
# City halalonot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=along
# Processing Record 14 of Set 4: along
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bethel
# Processing Record 15 of Set 4: bethel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=brookhaven
# Processing Record 16 of Set 4: brookhaven
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hobyo
# Processing Record 17 of Set 4: hobyo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saint-joseph
# Processing Record 18 of Set 4: saint-joseph
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=viedma
# Processing Record 19 of Set 4: viedma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=goycay
# Processing Record 20 of Set 4: goycay
# City goycaynot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=porto+walter
# Processing Record 21 of Set 4: porto walter
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lorengau
# Processing Record 22 of Set 4: lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=puerto+pinasco
# Processing Record 23 of Set 4: puerto pinasco
# City puerto pinasconot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=alice+springs
# Processing Record 24 of Set 4: alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=saldanha
# Processing Record 25 of Set 4: saldanha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tautira
# Processing Record 26 of Set 4: tautira
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vila+do+maio
# Processing Record 27 of Set 4: vila do maio
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=gat
# Processing Record 28 of Set 4: gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=marcona
# Processing Record 29 of Set 4: marcona
# City marconanot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=husavik
# Processing Record 30 of Set 4: husavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=katherine
# Processing Record 31 of Set 4: katherine
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mlonggo
# Processing Record 32 of Set 4: mlonggo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bakchar
# Processing Record 33 of Set 4: bakchar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=limoux
# Processing Record 34 of Set 4: limoux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=luxor
# Processing Record 35 of Set 4: luxor
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=mattru
# Processing Record 36 of Set 4: mattru
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=chapais
# Processing Record 37 of Set 4: chapais
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cervo
# Processing Record 38 of Set 4: cervo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ituni
# Processing Record 39 of Set 4: ituni
# City ituninot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=bafang
# Processing Record 40 of Set 4: bafang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=klaksvik
# Processing Record 41 of Set 4: klaksvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=adrar
# Processing Record 42 of Set 4: adrar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=terrace
# Processing Record 43 of Set 4: terrace
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=azul
# Processing Record 44 of Set 4: azul
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# ...
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vermilion
# Processing Record 11 of Set 14: vermilion
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=padilla
# Processing Record 12 of Set 14: padilla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=batagay
# Processing Record 13 of Set 14: batagay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lopandino
# Processing Record 14 of Set 14: lopandino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sangar
# Processing Record 15 of Set 14: sangar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=hinton
# Processing Record 16 of Set 14: hinton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kazalinsk
# Processing Record 17 of Set 14: kazalinsk
# City kazalinsknot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sovetskiy
# Processing Record 18 of Set 14: sovetskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=boone
# Processing Record 19 of Set 14: boone
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=lagos
# Processing Record 20 of Set 14: lagos
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=varkaus
# Processing Record 21 of Set 14: varkaus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=rafsanjan
# Processing Record 22 of Set 14: rafsanjan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=songjianghe
# Processing Record 23 of Set 14: songjianghe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=abu+samrah
# Processing Record 24 of Set 14: abu samrah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=neiafu
# Processing Record 25 of Set 14: neiafu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=nemuro
# Processing Record 26 of Set 14: nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=baghdad
# Processing Record 27 of Set 14: baghdad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=malatya
# Processing Record 28 of Set 14: malatya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=briceno
# Processing Record 29 of Set 14: briceno
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=port+hedland
# Processing Record 30 of Set 14: port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=anloga
# Processing Record 31 of Set 14: anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sinjar
# Processing Record 32 of Set 14: sinjar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=skjervoy
# Processing Record 33 of Set 14: skjervoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=panzhihua
# Processing Record 34 of Set 14: panzhihua
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=agucadoura
# Processing Record 35 of Set 14: agucadoura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=reconquista
# Processing Record 36 of Set 14: reconquista
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vaitape
# Processing Record 37 of Set 14: vaitape
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=benxi
# Processing Record 38 of Set 14: benxi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=yuzhno-kurilsk
# Processing Record 39 of Set 14: yuzhno-kurilsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=karamea
# Processing Record 40 of Set 14: karamea
# City karameanot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=na+wa
# Processing Record 41 of Set 14: na wa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=letterkenny
# Processing Record 42 of Set 14: letterkenny
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=maarianhamina
# Processing Record 43 of Set 14: maarianhamina
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=boda
# Processing Record 44 of Set 14: boda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=beringovskiy
# Processing Record 45 of Set 14: beringovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=severo-yeniseyskiy
# Processing Record 46 of Set 14: severo-yeniseyskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=burnie
# Processing Record 47 of Set 14: burnie
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cayenne
# Processing Record 48 of Set 14: cayenne
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=sabha
# Processing Record 49 of Set 14: sabha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=quatre+cocos
# Processing Record 50 of Set 14: quatre cocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=manta
# Processing Record 1 of Set 15: manta
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=aykhal
# Processing Record 2 of Set 15: aykhal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=salvador
# Processing Record 3 of Set 15: salvador
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=braganca
# Processing Record 4 of Set 15: braganca
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=qandala
# Processing Record 5 of Set 15: qandala
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=vanimo
# Processing Record 6 of Set 15: vanimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=rodino
# Processing Record 7 of Set 15: rodino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=palabuhanratu
# Processing Record 8 of Set 15: palabuhanratu
# City palabuhanratunot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=itoman
# Processing Record 9 of Set 15: itoman
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=brae
# Processing Record 10 of Set 15: brae
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=abnub
# Processing Record 11 of Set 15: abnub
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=tommot
# Processing Record 12 of Set 15: tommot
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=irbit
# Processing Record 13 of Set 15: irbit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=myanaung
# Processing Record 14 of Set 15: myanaung
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=dawson+creek
# Processing Record 15 of Set 15: dawson creek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=coffs+harbour
# Processing Record 16 of Set 15: coffs harbour
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=antsohihy
# Processing Record 17 of Set 15: antsohihy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=kudat
# Processing Record 18 of Set 15: kudat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=omboue
# Processing Record 19 of Set 15: omboue
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=las+tunas
# Processing Record 20 of Set 15: las tunas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=morden
# Processing Record 21 of Set 15: morden
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=benalla
# Processing Record 22 of Set 15: benalla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=ciro+marina
# Processing Record 23 of Set 15: ciro marina
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=turtkul
# Processing Record 24 of Set 15: turtkul
# City turtkulnot found. Skipping.......
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a98119a7c21e474f3cde09aa9f1234fa&q=cartagena
# Processing Record 25 of Set 15: cartagena
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to dataframe
city_data_df = pd.DataFrame(city_data)

# Exporting the DF data to a csv
output_datafile = "WeatherPy_Database.csv"
city_data_df.to_csv(output_datafile,index_label="City_ID")
